# %%
import pandas as pd
import matplotlib.pyplot as plt
df = pd.read_csv("pose_detection/a.csv")
time_col = "Frame"
ldf_col = "LDF_bloodflow"

#gets every column that starts with "angle_"
angle_cols = [col for col in df.columns if col.startswith("angle_")]

for angle_col in angle_cols:
    plt.figure(figsize=(10,5))

    #left y-axis: angle
    plt.plot(df[time_col], df[angle_col], label=angle_col)
    plt.xlabel("Time (sec)")
    plt.ylabel("Angle")

    #right y-axis: LDF blood flow
    ax1 = plt.gca()
    ax2 = ax1.twinx()
    ax2.plot(df[time_col],df[ldf_col], label="LDF blood flow", color="red", linestyle="--")
    ax2.set_ylabel("LDF blood flow")

    plt.title(f"Time vs {angle_col} and LDF blood flow")

    #combine legends from both y-axes
    lines1, labels1 = ax1.get_legend_handles_labels()
    lines2, labels2 = ax2.get_legend_handles_labels()
    ax1.legend(lines1 + lines2, labels1 + labels2)

    plt.show()

# %%
import matplotlib.pyplot as plt
seconds = [1,2,3,4,5,6,7]
ldf_data = [30, 22, 23, 27, 17, 18, 19]
plt.plot(seconds, ldf_data)

# %%
import pandas as pd
df = pd.read_csv("compileddata.csv")
df
# Out:
#    time_sec  angle_11_13_15_at_13  angle_12_14_16_at_14  angle_11_13_23_at_13  \
# 0         0            106.216343             99.234466            127.670161
# 1         1            115.201621            126.284036            105.733183
# 2         2            131.606901            145.544502             69.990463
# 3         3            143.684612            148.772049             56.995597
# 4         4            151.486964            135.083241             44.845324
# 5         5            146.892032            126.186524             42.995415
# 6         6            140.418516            116.521048             38.589580
# 7         7            133.991858            116.527649             26.887558
# 8         8            128.865157            110.021410             20.829814
# 9         9            112.752008            102.117098             23.906136
#
#    angle_12_14_24_at_14  angle_11_23_25_at_23  angle_12_24_26_at_24  \
# 0            144.383941            144.636085            138.215192
# 1            142.546656            136.643509            122.191963
# 2            107.731541            146.018707            123.918922
# 3             97.754708            145.002128            136.572402
# 4            125.537177            134.294617            126.508150
# 5            120.135435            146.028617            121.724151
# 6            123.833640            139.202092            122.401363
# 7            131.286741            129.462348            108.377098
# 8            131.487591            117.422893            102.611101
# 9            128.144476            114.578199            112.012740
#
#    LDF_bloodflow   segment
# 0           46.9  baseline
# 1           11.0  baseline
# 2            6.0  baseline
# 3            7.7  baseline
# 4            8.3  baseline
# 5           10.7  baseline
# 6           16.5  baseline
# 7           23.2  baseline
# 8           28.6  baseline
# 9           21.1  baseline
