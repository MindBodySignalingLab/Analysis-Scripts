# %% [markdown]
# # 1. Video to Coordinates #

# %%
from helpers.video_to_coord import process_video

VIDEO_PATH = "./test_video.mp4"
MODEL_PATH = "./pose_landmarker_lite.task"
OUTPUT_PATH = "./pose_output_video.mp4"

PROCESS_EVERY_N_FRAMES = 3
PROCESS_FIRST_N_SECONDS = None
SKIP_UNPROCESSED_FRAMES = True


detected_landmarks = process_video(
    video_path=VIDEO_PATH,
    model_path=MODEL_PATH,
    output_path=OUTPUT_PATH,
    process_every_n_frames=PROCESS_EVERY_N_FRAMES,
    process_first_n_seconds=PROCESS_FIRST_N_SECONDS,
    skip_unprocessed_frames=SKIP_UNPROCESSED_FRAMES,
)


from helpers.video_to_coord import landmarks_to_dataframe
df = landmarks_to_dataframe(detected_landmarks)
df
# Out:
# Video info:
#   - FPS: 30
#   - Resolution: 1920x1080
#   - Total frames: 12622
#   - Duration: 420.73 seconds
#   - Processing full video
#   - Processing every 3 frames (~4208 frames will be analyzed)
#
# Starting processing...
#   Processed 30 frames (frame #87)
#   Processed 60 frames (frame #177)
#   Processed 90 frames (frame #267)
#   Processed 120 frames (frame #357)
#   Processed 150 frames (frame #447)
#   Processed 180 frames (frame #537)
#   Processed 210 frames (frame #627)
#   Processed 240 frames (frame #717)
#   Processed 270 frames (frame #807)
#   Processed 300 frames (frame #897)
#   Processed 330 frames (frame #987)
#   Processed 360 frames (frame #1077)
#   Processed 390 frames (frame #1167)
#   Processed 420 frames (frame #1257)
#   Processed 450 frames (frame #1347)
#   Processed 480 frames (frame #1437)
#   Processed 510 frames (frame #1527)
#   Processed 540 frames (frame #1617)
#   Processed 570 frames (frame #1707)
#   Processed 600 frames (frame #1797)
#   Processed 630 frames (frame #1887)
#   Processed 660 frames (frame #1977)
#   Processed 690 frames (frame #2067)
#   Processed 720 frames (frame #2157)
#   Processed 750 frames (frame #2247)
#   Processed 780 frames (frame #2337)
#   Processed 810 frames (frame #2427)
#   Processed 840 frames (frame #2517)
#   Processed 870 frames (frame #2607)
#   Processed 900 frames (frame #2697)
#   Processed 930 frames (frame #2787)
#   Processed 960 frames (frame #2877)
#   Processed 990 frames (frame #2967)
#   Processed 1020 frames (frame #3057)
#   Processed 1050 frames (frame #3147)
#   Processed 1080 frames (frame #3237)
#   Processed 1110 frames (frame #3327)
#   Processed 1140 frames (frame #3417)
#   Processed 1170 frames (frame #3507)
#   Processed 1200 frames (frame #3597)
#   Processed 1230 frames (frame #3687)
#   Processed 1260 frames (frame #3777)
#   Processed 1290 frames (frame #3867)
#   Processed 1320 frames (frame #3957)
#   Processed 1350 frames (frame #4047)
#   Processed 1380 frames (frame #4137)
#   Processed 1410 frames (frame #4227)
#   Processed 1440 frames (frame #4317)
#   Processed 1470 frames (frame #4407)
#   Processed 1500 frames (frame #4497)
#   Processed 1530 frames (frame #4587)
#   Processed 1560 frames (frame #4677)
#   Processed 1590 frames (frame #4767)
#   Processed 1620 frames (frame #4857)
#   Processed 1650 frames (frame #4947)
#   Processed 1680 frames (frame #5037)
#   Processed 1710 frames (frame #5127)
#   Processed 1740 frames (frame #5217)
#   Processed 1770 frames (frame #5307)
#   Processed 1800 frames (frame #5397)
#   Processed 1830 frames (frame #5487)
#   Processed 1860 frames (frame #5577)
#   Processed 1890 frames (frame #5667)
#   Processed 1920 frames (frame #5757)
#   Processed 1950 frames (frame #5847)
#   Processed 1980 frames (frame #5937)
#   Processed 2010 frames (frame #6027)
#   Processed 2040 frames (frame #6117)
#   Processed 2070 frames (frame #6207)
#   Processed 2100 frames (frame #6297)
#   Processed 2130 frames (frame #6387)
#   Processed 2160 frames (frame #6477)
#   Processed 2190 frames (frame #6567)
#   Processed 2220 frames (frame #6657)
#   Processed 2250 frames (frame #6747)
#   Processed 2280 frames (frame #6837)
#   Processed 2310 frames (frame #6927)
#   Processed 2340 frames (frame #7017)
#   Processed 2370 frames (frame #7107)
#   Processed 2400 frames (frame #7197)
#   Processed 2430 frames (frame #7287)
#   Processed 2460 frames (frame #7377)
#   Processed 2490 frames (frame #7467)
#   Processed 2520 frames (frame #7557)
#   Processed 2550 frames (frame #7647)
#   Processed 2580 frames (frame #7737)
#   Processed 2610 frames (frame #7827)
#   Processed 2640 frames (frame #7917)
#   Processed 2670 frames (frame #8007)
#   Processed 2700 frames (frame #8097)
#   Processed 2730 frames (frame #8187)
#   Processed 2760 frames (frame #8277)
#   Processed 2790 frames (frame #8367)
#   Processed 2820 frames (frame #8457)
#   Processed 2850 frames (frame #8547)
#   Processed 2880 frames (frame #8637)
#   Processed 2910 frames (frame #8727)
#   Processed 2940 frames (frame #8817)
#   Processed 2970 frames (frame #8907)
#   Processed 3000 frames (frame #8997)
#   Processed 3030 frames (frame #9087)
#   Processed 3060 frames (frame #9177)
#   Processed 3090 frames (frame #9267)
#   Processed 3120 frames (frame #9357)
#   Processed 3150 frames (frame #9447)
#   Processed 3180 frames (frame #9537)
#   Processed 3210 frames (frame #9627)
#   Processed 3240 frames (frame #9717)
#   Processed 3270 frames (frame #9807)
#   Processed 3300 frames (frame #9897)
#   Processed 3330 frames (frame #9987)
#   Processed 3360 frames (frame #10077)
#   Processed 3390 frames (frame #10167)
#   Processed 3420 frames (frame #10257)
#   Processed 3450 frames (frame #10347)
#   Processed 3480 frames (frame #10437)
#   Processed 3510 frames (frame #10527)
#   Processed 3540 frames (frame #10617)
#   Processed 3570 frames (frame #10707)
#   Processed 3600 frames (frame #10797)
#   Processed 3630 frames (frame #10887)
#   Processed 3660 frames (frame #10977)
#   Processed 3690 frames (frame #11067)
#   Processed 3720 frames (frame #11157)
#   Processed 3750 frames (frame #11247)
#   Processed 3780 frames (frame #11337)
#   Processed 3810 frames (frame #11427)
#   Processed 3840 frames (frame #11517)
#   Processed 3870 frames (frame #11607)
#   Processed 3900 frames (frame #11697)
#   Processed 3930 frames (frame #11787)
#   Processed 3960 frames (frame #11877)
#   Processed 3990 frames (frame #11967)
#   Processed 4020 frames (frame #12057)
#   Processed 4050 frames (frame #12147)
#   Processed 4080 frames (frame #12237)
#   Processed 4110 frames (frame #12327)
#   Processed 4140 frames (frame #12417)
#   Processed 4170 frames (frame #12507)
#   Processed 4200 frames (frame #12597)
#
# ✓ Processing complete!
#   - Total frames in output: 12622
#   - Frames with pose detection attempted: 4208
#   - Frames skipped: 8414
#   - Frames with detected pose: 4208
#   - Output video saved to: ./pose_output_video.mp4
#       Frame                     p11                     p12  \
# 0         0                     NaN                     NaN
# 1         3                     NaN                     NaN
# 2         6                     NaN                     NaN
# 3         9   (0.743, 0.107, 0.329)   (0.755, 0.124, 0.183)
# 4        12  (0.719, 0.027, -0.030)  (0.800, 0.156, -0.181)
# ...     ...                     ...                     ...
# 4203  12609  (0.714, 0.686, -0.455)  (0.345, 0.655, -0.530)
# 4204  12612  (0.714, 0.679, -0.505)  (0.345, 0.655, -0.546)
# 4205  12615  (0.709, 0.679, -0.457)  (0.343, 0.658, -0.584)
# 4206  12618  (0.715, 0.679, -0.507)  (0.343, 0.656, -0.602)
# 4207  12621  (0.715, 0.686, -0.512)  (0.342, 0.660, -0.622)
#
#                          p13                     p14                     p15  \
# 0                        NaN                     NaN                     NaN
# 1                        NaN                     NaN                     NaN
# 2                        NaN                     NaN                     NaN
# 3      (0.780, 0.313, 0.295)   (0.801, 0.341, 0.168)   (0.862, 0.345, 0.233)
# 4      (0.704, 0.271, 0.128)  (0.847, 0.384, -0.084)   (0.746, 0.398, 0.235)
# ...                      ...                     ...                     ...
# 4203  (0.732, 1.125, -0.366)  (0.224, 1.014, -0.503)  (0.743, 1.541, -0.646)
# 4204  (0.732, 1.126, -0.435)  (0.227, 1.018, -0.521)  (0.745, 1.533, -0.717)
# 4205  (0.723, 1.117, -0.365)  (0.227, 1.023, -0.558)  (0.742, 1.530, -0.662)
# 4206  (0.723, 1.116, -0.426)  (0.227, 1.030, -0.575)  (0.739, 1.524, -0.729)
# 4207  (0.726, 1.125, -0.428)  (0.216, 1.060, -0.587)  (0.738, 1.532, -0.720)
#
#                          p16                    p23                     p24  \
# 0                        NaN                    NaN                     NaN
# 1                        NaN                    NaN                     NaN
# 2                        NaN                    NaN                     NaN
# 3      (0.887, 0.359, 0.261)  (0.655, 0.387, 0.071)  (0.647, 0.397, -0.071)
# 4      (0.887, 0.370, 0.140)  (0.621, 0.404, 0.070)  (0.653, 0.487, -0.069)
# ...                      ...                    ...                     ...
# 4203  (0.186, 1.449, -0.700)  (0.620, 1.582, 0.040)  (0.391, 1.539, -0.033)
# 4204  (0.181, 1.471, -0.765)  (0.620, 1.572, 0.038)  (0.392, 1.521, -0.031)
# 4205  (0.184, 1.475, -0.761)  (0.620, 1.573, 0.062)  (0.392, 1.535, -0.055)
# 4206  (0.199, 1.473, -0.783)  (0.622, 1.571, 0.066)  (0.395, 1.530, -0.058)
# 4207  (0.200, 1.536, -0.781)  (0.623, 1.594, 0.065)  (0.386, 1.579, -0.057)
#
#                         p25                     p26                     p27  \
# 0                       NaN                     NaN                     NaN
# 1                       NaN                     NaN                     NaN
# 2                       NaN                     NaN                     NaN
# 3     (0.698, 0.711, 0.003)  (0.695, 0.685, -0.117)  (0.693, 1.007, -0.056)
# 4     (0.719, 0.582, 0.102)  (0.772, 0.602, -0.003)   (0.737, 0.751, 0.227)
# ...                     ...                     ...                     ...
# 4203  (0.583, 2.305, 0.053)  (0.358, 2.308, -0.035)   (0.552, 2.889, 0.581)
# 4204  (0.584, 2.297, 0.048)  (0.362, 2.304, -0.039)   (0.554, 2.875, 0.561)
# 4205  (0.585, 2.300, 0.051)  (0.363, 2.312, -0.070)   (0.557, 2.877, 0.609)
# 4206  (0.601, 2.300, 0.040)  (0.373, 2.309, -0.141)   (0.585, 2.881, 0.597)
# 4207  (0.608, 2.342, 0.047)  (0.377, 2.345, -0.126)   (0.600, 2.909, 0.651)
#
#                          p28
# 0                        NaN
# 1                        NaN
# 2                        NaN
# 3     (0.673, 1.025, -0.254)
# 4      (0.759, 0.764, 0.087)
# ...                      ...
# 4203   (0.330, 2.916, 0.342)
# 4204   (0.334, 2.901, 0.335)
# 4205   (0.334, 2.910, 0.318)
# 4206   (0.349, 2.913, 0.222)
# 4207   (0.363, 2.943, 0.343)
#
# [4208 rows x 13 columns]

# %% [markdown]
# # 2. Process Coordinates --> Convert to Angles + Additional Features #

# %%
from helpers.calculated_feature import calculate_motion_features_df
# angle1	(11, 13, 15)	Left elbow
# angle2	(12, 14, 16)	Right elbow
# angle3	(11, 13, 23)	Left shoulder
# angle4	(12, 14, 24)	Right shoulder
# angle5	(11, 23, 25)	Left hip
# angle6	(12, 24, 26)	Right hip

feature_df = calculate_motion_features_df(
    df,
    fps=30,
    rom_window_seconds=1.0,
)
feature_df
# Out:
#         Frame  time_sec  angle_1_deg  angle_2_deg  angle_3_deg  angle_4_deg  \
# 0         0.0       0.0          NaN          NaN          NaN          NaN
# 1         3.0       0.1          NaN          NaN          NaN          NaN
# 2         6.0       0.2          NaN          NaN          NaN          NaN
# 3         9.0       0.3   120.929514   103.141152   108.790975    97.718601
# 4        12.0       0.4   161.430447   110.799567   120.279284   106.555600
# ...       ...       ...          ...          ...          ...          ...
# 4203  12609.0     420.3   134.607687   148.689777   147.412349   131.142371
# 4204  12612.0     420.4   136.401115   145.972777   140.488979   129.462214
# 4205  12615.0     420.5   132.445256   149.611103   146.925900   129.761646
# 4206  12618.0     420.6   132.909126   148.080863   142.151303   128.753927
# 4207  12621.0     420.7   133.524873   149.060703   143.134739   129.735981
#
#       angle_5_deg  angle_6_deg  angular_velocity_1_deg_per_s  \
# 0             NaN          NaN                           NaN
# 1             NaN          NaN                           NaN
# 2             NaN          NaN                           NaN
# 3      143.213642   137.889257                           NaN
# 4      137.205087   114.458294                    405.009328
# ...           ...          ...                           ...
# 4203   152.089341   150.085105                    -13.374768
# 4204   149.479314   148.309288                     17.934276
# 4205   148.993890   147.439015                    -39.558592
# 4206   145.144578   141.765617                      4.638698
# 4207   146.034985   143.155068                      6.157477
#
#       angular_velocity_2_deg_per_s  ...  vertex_speed_angle_6_p24_coord_per_s  \
# 0                              NaN  ...                                   NaN
# 1                              NaN  ...                                   NaN
# 2                              NaN  ...                                   NaN
# 3                              NaN  ...                                   NaN
# 4                        76.584153  ...                              0.902219
# ...                            ...  ...                                   ...
# 4203                    -26.207234  ...                              0.010000
# 4204                    -27.169998  ...                              0.181384
# 4205                     36.383259  ...                              0.277849
# 4206                    -15.302399  ...                              0.065574
# 4207                      9.798402  ...                              0.498297
#
#       rom_1s_angle_1_deg  rom_1s_angle_2_deg  rom_1s_angle_3_deg  \
# 0                    NaN                 NaN                 NaN
# 1                    NaN                 NaN                 NaN
# 2                    NaN                 NaN                 NaN
# 3               0.000000            0.000000            0.000000
# 4              40.500933            7.658415           11.488309
# ...                  ...                 ...                 ...
# 4203           11.091634           44.263023           25.384333
# 4204           11.091634           44.263023           25.384333
# 4205            8.496283           44.263023           22.247553
# 4206            8.496283           41.999050           22.247553
# 4207            8.496283           41.999050           22.247553
#
#       rom_1s_angle_4_deg  rom_1s_angle_5_deg  rom_1s_angle_6_deg  \
# 0                    NaN                 NaN                 NaN
# 1                    NaN                 NaN                 NaN
# 2                    NaN                 NaN                 NaN
# 3               0.000000            0.000000            0.000000
# 4               8.836999            6.008555           23.430963
# ...                  ...                 ...                 ...
# 4203           68.888393           13.265834           18.623139
# 4204           68.888393           13.265834           18.623139
# 4205           68.888393           13.265834           18.426938
# 4206           68.888393           13.265834           18.426938
# 4207           68.888393           13.265834           18.426938
#
#       symmetry_absdiff_angle_1_vs_2_deg  symmetry_absdiff_angle_3_vs_4_deg  \
# 0                                   NaN                                NaN
# 1                                   NaN                                NaN
# 2                                   NaN                                NaN
# 3                             17.788362                          11.072374
# 4                             50.630880                          13.723684
# ...                                 ...                                ...
# 4203                          14.082090                          16.269977
# 4204                           9.571662                          11.026765
# 4205                          17.165847                          17.164253
# 4206                          15.171738                          13.397376
# 4207                          15.535830                          13.398758
#
#       symmetry_absdiff_angle_5_vs_6_deg
# 0                                   NaN
# 1                                   NaN
# 2                                   NaN
# 3                              5.324385
# 4                             22.746794
# ...                                 ...
# 4203                           2.004236
# 4204                           1.170026
# 4205                           1.554875
# 4206                           3.378961
# 4207                           2.879917
#
# [4208 rows x 29 columns]

# %% [markdown]
# # 3. Add in LDF #

# %%
from helpers.read_ldf import readLDFdata
LDF_bloodflow = readLDFdata("./test_video-ldf")
LDF_bloodflow.extend([None] * (len(feature_df) - len(LDF_bloodflow)))
feature_df['LDF_bloodflow'] = LDF_bloodflow
feature_df
# Out:
#         Frame  time_sec  angle_1_deg  angle_2_deg  angle_3_deg  angle_4_deg  \
# 0         0.0       0.0          NaN          NaN          NaN          NaN
# 1         3.0       0.1          NaN          NaN          NaN          NaN
# 2         6.0       0.2          NaN          NaN          NaN          NaN
# 3         9.0       0.3   120.929514   103.141152   108.790975    97.718601
# 4        12.0       0.4   161.430447   110.799567   120.279284   106.555600
# ...       ...       ...          ...          ...          ...          ...
# 4203  12609.0     420.3   134.607687   148.689777   147.412349   131.142371
# 4204  12612.0     420.4   136.401115   145.972777   140.488979   129.462214
# 4205  12615.0     420.5   132.445256   149.611103   146.925900   129.761646
# 4206  12618.0     420.6   132.909126   148.080863   142.151303   128.753927
# 4207  12621.0     420.7   133.524873   149.060703   143.134739   129.735981
#
#       angle_5_deg  angle_6_deg  angular_velocity_1_deg_per_s  \
# 0             NaN          NaN                           NaN
# 1             NaN          NaN                           NaN
# 2             NaN          NaN                           NaN
# 3      143.213642   137.889257                           NaN
# 4      137.205087   114.458294                    405.009328
# ...           ...          ...                           ...
# 4203   152.089341   150.085105                    -13.374768
# 4204   149.479314   148.309288                     17.934276
# 4205   148.993890   147.439015                    -39.558592
# 4206   145.144578   141.765617                      4.638698
# 4207   146.034985   143.155068                      6.157477
#
#       angular_velocity_2_deg_per_s  ...  rom_1s_angle_1_deg  \
# 0                              NaN  ...                 NaN
# 1                              NaN  ...                 NaN
# 2                              NaN  ...                 NaN
# 3                              NaN  ...            0.000000
# 4                        76.584153  ...           40.500933
# ...                            ...  ...                 ...
# 4203                    -26.207234  ...           11.091634
# 4204                    -27.169998  ...           11.091634
# 4205                     36.383259  ...            8.496283
# 4206                    -15.302399  ...            8.496283
# 4207                      9.798402  ...            8.496283
#
#       rom_1s_angle_2_deg  rom_1s_angle_3_deg  rom_1s_angle_4_deg  \
# 0                    NaN                 NaN                 NaN
# 1                    NaN                 NaN                 NaN
# 2                    NaN                 NaN                 NaN
# 3               0.000000            0.000000            0.000000
# 4               7.658415           11.488309            8.836999
# ...                  ...                 ...                 ...
# 4203           44.263023           25.384333           68.888393
# 4204           44.263023           25.384333           68.888393
# 4205           44.263023           22.247553           68.888393
# 4206           41.999050           22.247553           68.888393
# 4207           41.999050           22.247553           68.888393
#
#       rom_1s_angle_5_deg  rom_1s_angle_6_deg  \
# 0                    NaN                 NaN
# 1                    NaN                 NaN
# 2                    NaN                 NaN
# 3               0.000000            0.000000
# 4               6.008555           23.430963
# ...                  ...                 ...
# 4203           13.265834           18.623139
# 4204           13.265834           18.623139
# 4205           13.265834           18.426938
# 4206           13.265834           18.426938
# 4207           13.265834           18.426938
#
#       symmetry_absdiff_angle_1_vs_2_deg  symmetry_absdiff_angle_3_vs_4_deg  \
# 0                                   NaN                                NaN
# 1                                   NaN                                NaN
# 2                                   NaN                                NaN
# 3                             17.788362                          11.072374
# 4                             50.630880                          13.723684
# ...                                 ...                                ...
# 4203                          14.082090                          16.269977
# 4204                           9.571662                          11.026765
# 4205                          17.165847                          17.164253
# 4206                          15.171738                          13.397376
# 4207                          15.535830                          13.398758
#
#       symmetry_absdiff_angle_5_vs_6_deg  LDF_bloodflow
# 0                                   NaN           33.1
# 1                                   NaN           13.8
# 2                                   NaN            5.1
# 3                              5.324385           45.4
# 4                             22.746794           65.3
# ...                                 ...            ...
# 4203                           2.004236            NaN
# 4204                           1.170026            NaN
# 4205                           1.554875            NaN
# 4206                           3.378961            NaN
# 4207                           2.879917            NaN
#
# [4208 rows x 30 columns]

# %% [markdown]
# # 4. Save the data

# %%
import pandas as pd
feature_df.to_csv("test_video.csv")
